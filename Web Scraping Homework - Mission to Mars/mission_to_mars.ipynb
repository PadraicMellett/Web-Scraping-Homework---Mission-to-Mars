# %%
#Import Dependancies

from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# Driver [C:\Users\pmellett\.wdm\drivers\chromedriver\win32\94.0.4606.61\chromedriver.exe] found in cache

# %%
url = "https://redplanetscience.com"
browser.visit(url)

# %% [markdown]
# ### NASA Mars News

# %%
response = requests.get(url)

# %%
html = browser.html

# %%
soup = soup(html, 'html.parser')
target_news = soup.select_one('div.list_text')
slide_elem = target_news.select_one('div.list_text')

# %%
target_news1 = target_news.find('div', class_= 'content_title' )
print(target_news1)
# Out:
# <div class="content_title">InSight's 'Mole' Team Peers into the Pit</div>

# %%
target_news = target_news.find("div", class_="content_title").get_text()
print(target_news)
# Out:
# InSight's 'Mole' Team Peers into the Pit

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
#   <link href="css/font.css" rel="stylesheet" type="text/css"/>
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
#   <title>
#    News - Mars Exploration Program
#   </title>
#  </head>
#  <body>
#   <div class="col-md-12">
#    <div class="row">
#     <nav class="navbar navbar-expand-lg navbar-light fixed-top">
#      <div class="container-fluid">
#       <a class="navbar-brand" href="#">
# ...

# %%
#news_title = "NASA's Mars 2020 Rover Tests Descent-Stage Separation"
#news_paragraph = "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft."

# %% [markdown]
# ### JPL Mars Space Images - Featured Image

# %%
# https://spaceimages-mars.com
featured_image_url = "https://spaceimages-mars.com/image/mars/South%20Polar%20Cap.jpg"
browser.visit(featured_image_url)

# %% [markdown]
# ### Mars Facts
# url1 = 'https://galaxyfacts-mars.com'

# %%
url1 = 'https://galaxyfacts-mars.com'

# %%
tables = pd.read_html(url1)[0]
print(tables)
tables.reset_index(inplace=True)
tables.columns=["ID", "Properties","Mars", "Earth"]
tables
# Out:
#                          0                1                2
# 0  Mars - Earth Comparison             Mars            Earth
# 1                Diameter:         6,779 km        12,742 km
# 2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 3                   Moons:                2                1
# 4       Distance from Sun:   227,943,824 km   149,598,262 km
# 5          Length of Year:   687 Earth days      365.24 days
# 6             Temperature:     -87 to -5 °C      -88 to 58°C
#    ID               Properties             Mars            Earth
# 0   0  Mars - Earth Comparison             Mars            Earth
# 1   1                Diameter:         6,779 km        12,742 km
# 2   2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 3   3                   Moons:                2                1
# 4   4       Distance from Sun:   227,943,824 km   149,598,262 km
# 5   5          Length of Year:   687 Earth days      365.24 days
# ...

# %%
html_table = tables.to_html()
html_table
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>ID</th>      <th>Properties</th>      <th>Mars</th>      <th>Earth</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>0</td>      <td>Mars - Earth Comparison</td>      <td>Mars</td>      <td>Earth</td>    </tr>    <tr>      <th>1</th>      <td>1</td>      <td>Diameter:</td>      <td>6,779 km</td>      <td>12,742 km</td>    </tr>    <tr>      <th>2</th>      <td>2</td>      <td>Mass:</td>      <td>6.39 × 10^23 kg</td>      <td>5.97 × 10^24 kg</td>    </tr>    <tr>      <th>3</th>      <td>3</td>      <td>Moons:</td>      <td>2</td>      <td>1</td>    </tr>    <tr>      <th>4</th>      <td>4</td>      <td>Distance from Sun:</td>      <td>227,943,824 km</td>      <td>149,598,262 km</td>    </tr>    <tr>      <th>5</th>      <td>5</td>      <td>Length of Year:</td>      <td>687 Earth days</td>      <td>365.24 days</td>    </tr>    <tr>      <th>6</th>      <td>6</td>  
# ...

# %%
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>ID</th>\n      <th>Properties</th>\n      <th>Mars</th>\n      <th>Earth</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>Mars - Earth Comparison</td>\n      <td>Mars</td>\n      <td>Earth</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Diameter:</td>\n      <td>6,779 km</td>\n      <td>12,742 km</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>Mass:</td>\n      <td>6.39 × 10^23 kg</td>\n      <td>5.97 × 10^24 kg</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>3</td>\n      <td>Moons:</td>\n      <td>2</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>4</td>\n      <td>Distance from Sun:</td>\n      <td>227,943,824 km</td>\n      <td>149,598,262 km</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>5</td>\n      <td>Length of Year:</td>\n      
# ...

# %%
# https://marshemispheres.com)

url ='https://marshemispheres.com'

browser.visit(url)

# %%
#time.sleep(5)

hemisphere_html = browser.html
soup = soup(hemisphere_html, 'html.parser')

# %%
hemi_images = soup.find_all("div", class_= "item")

images =[]

links = browser.find_by_css('a.product-item img")

for i in hemi_images
    images.append(f"{url}{i.find('a', class_='itemLink')['href']}")

    print(images)
# Out:
#   File "<ipython-input-47-7d7bd89940cb>", line 5
#     links = browser.find_by_css('a.product-item img")
#                                                      ^
# SyntaxError: EOL while scanning string literal

# %%
urls=[]

# Loop through each url
for url in urls:
    # Navigate to the page
    browser.visit(url)
    
    time.sleep(4)
    
    # Assign the HTML content of the page to a variable
    hemisphere_html = browser.html
    # Parse HTML with Beautifulsoup
    soup = soup(hemisphere_html,'html.parser')
    
    img_url = soup.find('img', class_="wide-image")['src']
    title = soup.find('h2', class_="title").text
    
    urls.append({"title":title,"img_url":f"https://astrogeology.usgs.gov{img_url}"})

# %%
urls

# %%
browser.quit
